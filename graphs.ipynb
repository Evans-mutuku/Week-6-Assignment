# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [3000, 4000, 1800, 2800, 812, 5000]

plt.plot(x, y)
plt.title("Python Class Attendance")
plt.xlabel(" Weeks")
plt.ylabel("Number of learners")
# Out:
# Text(0, 0.5, 'Number of learners')

# %%
jessica_languages = ["python", "webdev", "AI"]
language_score = [98, 50, 70]

plt.bar(jessica_languages, language_score, color=["purple", "pink", "yellow"])
plt.title("Jessica Language Profficiency")
plt.xlabel("Language")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
gift_shawries = ['Ann', 'Judith', 'Sheila', 'Jael']
shawries_positions = [1, 8, 2, 3]

plt.pie(shawries_numbers, labels=gift_shawries, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x70fdc6bb4590>,
# ...
#  [Text(-0.24477303810986795, 1.0724207009445805, 'Ann'),
#   Text(-0.8600145619153347, -0.68583886831644, 'Judith'),
#   Text(1.0724207525084946, -0.24477281219349972, 'Sheila'),
#   Text(0.6858385864950928, 0.8600147866603303, 'Jael')],
#  [Text(-0.13351256624174612, 0.5849567459697711, '7.1%'),
#   Text(-0.46909885195381884, -0.3740939281726036, '57.1%'),
#   Text(0.5849567740955425, -0.1335124430146362, '14.3%'),
#   Text(0.37409377445186875, 0.4690989745419983, '21.4%')])
